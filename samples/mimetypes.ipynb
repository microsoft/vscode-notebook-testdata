# %% [markdown]
# # Text

# %%
from __future__ import print_function
print('hi, stderr', file=sys.stderr)
# Out:
# hi, stderr

# %%
print(a + 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f270cadddfe4> in <module>
# ----> 1 print(a + 4)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Display Data

# %% [markdown]
# ## text/plain

# %%
from IPython.core.display import display, HTML
display(('Hello, world!'))
# Out:
# Hello World

# %% [markdown]
# ## text/markdown

# %%
# display markdown
# Out:
# # header 1
#
# body: [link](https://github.com)

# %% [markdown]
# ## text/html

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %% [markdown]
# ## application/javascript

# %%
from IPython.core.display import display, HTML
display(HTML('<script>hello world</script>'))

# %% [markdown]
# ## image/svg+xml

# %%
from IPython.core.display import SVG
SVG(url="https://mdn.mozillademos.org/files/3075/svgdemo1.xml")

# %% [markdown]
# ## image/png

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

s = pd.Series([1,2,3], index=['a','b','c'])

s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello World");

# %% [markdown]
# ## image/jpeg

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

s = pd.Series([1,2,3], index=['a','b','c'])

s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello World");

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

s = pd.Series([1,2,3], index=['a','b','c'])

s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello World");
